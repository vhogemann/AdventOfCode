// %%
open System.Text.RegularExpressions

let example = "xmul(2,4)%&mul[3,7]!@^do_not_mul(5,5)+mul(32,64]then(mul(11,8)mul(8,5))"

let mul = Regex(@"mul\(\d{1,3}\,\d{1,3}\)")
let digits = Regex(@"\d{1,3}")

mul.Matches(example)
|> Seq.map digits.Matches
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td>[ mul(2,4) ]</td></tr><tr><td>Success</td><td>True</td></tr><tr><td>Name</td><td>0</td></tr><tr><td>Captures</td><td>[ mul(2,4) ]</td></tr><tr><td>Index</td><td>1</td></tr><tr><td>Length</td><td>8</td></tr><tr><td>Value</td><td>mul(2,4)</td></tr><tr><td>ValueSpan</td><td>mul(2,4)</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Success</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Captures</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td>[ mul(2,4) ]</td></tr><tr><td>Success</td><td>True</td></tr><tr><td>Name</td><td>0</td></tr><tr><td>Captures</td><td>[ mul(2,4) ]</td></tr><tr><td>Index</td><td>1</td></tr><tr><td>Length</td><td>8</td></tr><tr><td>Value</td><td>mul(2,4)</td></tr><tr><td>ValueSpan</td><td>mul(2,4)</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>Length</td><td><div class="dni-plaintext"><pre>8</pre></div></td></tr><tr><td>Value</td><td><div class="dni-plaintext"><pre>mul(2,4)</pre></div></td></tr><tr><td>ValueSpan</td><td><div class="dni-plaintext"><pre>mul(2,4)</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Success</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Captures</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td>[ mul(2,4) ]</td></tr><tr><td>Success</td><td>True</td></tr><tr><td>Name</td><td>0</td></tr><tr><td>Captures</td><td>[ mul(2,4) ]</td></tr><tr><td>Index</td><td>1</td></tr><tr><td>Length</td><td>8</td></tr><tr><td>Value</td><td>mul(2,4)</td></tr><tr><td>ValueSpan</td><td>mul(2,4)</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Success</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Captures</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>mul(2,4)</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Groups</td><td>[ mul(2,4) ]</td></tr><tr><td>Success</td><td>True</td></tr><tr><td>Name</td><td>0</td></tr><tr><td>Captures</td><td>[ mul(2,4) ]</td></tr><tr><td>I ...
