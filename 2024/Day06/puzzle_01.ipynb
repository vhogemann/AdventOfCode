// %%
#!value --name example
....#.....
.........#
..........
..#.......
.......#..
..........
.#..^.....
........#.
#.........
......#...

// %%
#!share --from value example

type Point = 
    { 
        x:int 
        y:int 
    }
    static member (+) (p1:Point, p2:Point) = 
        { x = p1.x + p2.x ; y = p1.y + p2.y }

let Up = { x = 0; y = -1 }
let Down = { x = 0; y = 1 }
let Left = { x = -1; y = 0 }
let Right = { x = 1; y = 0 } 

type Block =
    | Guard of Point
    | Space
    | Obstacle

type Action =
    | Advance
    | Turn
    | Exit

let getDirection = function 
    | '>' -> Some Right
    | '^' -> Some Up
    | '<' -> Some Left
    | 'v' | 'V' -> Some Down
    | _ -> None

let nextDirection = function
    | { x = 0; y = -1 } -> Right
    | { x = -1; y = 0 } -> Up
    | { x = 0; y = 1 } -> Left
    | { x = 1; y = 0 } -> Down
    | direction -> direction

let parse (lines: string seq) = 
    lines
    |> Seq.map (
        Seq.map( fun c ->
            match c with
            | '#' -> Some Obstacle
            | '^' | '>' | 'v' | 'V' | '<' -> getDirection c |> Option.map (fun p -> Guard p)
            | '.' -> Some Space
            | _ -> None ) >> Seq.choose id
    )

let findGuards (map: Block seq seq) = 
    let lines = (map |> Seq.length) - 1
    let columns = (map |> Seq.head |> Seq.length) - 1

    seq {
        for y in 0..lines do
            for x in 0..columns do
                let block = map |> Seq.item y |> Seq.item x
                match block with
                | Guard direction -> yield Some ({x=x;y=y}, direction)
                | _ -> yield None
    } |> Seq.choose id

let blockAt map point =
    map |> Seq.item point.y |> Seq.item point.x

let check (from:Point) (direction:Point) (map: Block seq seq) =
    let width = (map |> Seq.head |> Seq.length) - 1
    let height = (map |> Seq.length) - 1
    let horizontal =
        match direction with 
        | { y = -1; x = _ } -> from.y > 0
        | { y = 1; x = _ }  -> from.y < height
        | _ -> true
    let vertical =
        match direction with
        | { y = _; x = -1 } -> from.x > 0
        | { y = _; x = 1 } -> from.x < width
        | _ -> true
    
    if horizontal && vertical then 
        match blockAt map (from + direction) with
        | Space | Guard _ -> Advance
        | Obstacle ->
            Turn
    else
        Exit

let rec step (steps:Point list) (from:Point) (direction:Point) (map: Block seq seq) =
    match check from direction map with
    | Advance -> step (from :: steps) (from + direction) direction map
    | Turn ->
        let newDirection = nextDirection direction 
        step (from :: steps) (from + newDirection) newDirection map
    | Exit -> from :: steps

let solution lines =
    let map = lines |> parse 
    map |> findGuards
    |> Seq.map( fun (position,direction) -> 
        step [] position direction map
    )
    |> Seq.map (Set.ofSeq >> Seq.length)
example.Split("\n") |> solution
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 41 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@729[Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point],System.Int32]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+Map@749-1[Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point],System.Int32]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>mapping</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>FSI_0128+solution@101-19</code></span></summary><div><table><thead><tr></tr></thead><tbody></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>ie</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ [ { x = 7
//   y = 9 }, { x = 7
//   y = 8 }, { x = 7
//   y = 7 }, { x = 6
//   y = 7 }, { x = 5
//   y = 7 }, { x = 4
//   y = 7 }, { x = 3
//   y = 7 }, { x = 2
//   y = 7 }, { x = 1
//   y = 7 }, { x = 1
//   y = 8 }, { x = 2
//   y = 8 }, { x = 3
//   y = 8 }, { x = 4
//   y = 8 }, { x = 5
//   y = 8 }, { x = 6
//   y = 8 }, { x = 6
//   y = 7 }, { x = 6
//   y = 6 }, { x = 6
//   y = 5 }, { x = 6
//   y = 4 }, { x = 5
//   y = 4 } ... (more) ] ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@729[System.Tuple`2[FSI_0128+Point,FSI_0128+Point],Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point]]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+Map@749-1[System.Tuple`2[FSI_0128+Point,FSI_0128+Point],Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point]]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>mapping</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>FSI_0128+solution@98-20</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>map</td><td>[ [ Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ], [ Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space ], [ Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ], [ Space, Obstacle, Space, Space, Guard { x = 0
//         y = -1 }, Space, Space, Space, Space, Space ], [ Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space ], [ Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space ], [ Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space ] ]</td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>ie</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ ({ x = 4
//   y = 6 }, { x = 0
//   y = -1 }) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@729[Microsoft.FSharp.Core.FSharpOption`1[System.Tuple`2[FSI_0128+Point,FSI_0128+Point]],System.Tuple`2[FSI_0128+Point,FSI_0128+Point]]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td>Microsoft.FSharp.Collections.SeqModule+Choose@778[Microsoft.FSharp.Core.FSharpOption`1[System.Tuple`2[FSI_0128+Point,FSI_0128+Point]],System.Tuple`2[FSI_0128+Point,FSI_0128+Point]]</td></tr><tr><td>ie</td><td>[ <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null> ... (more) ]</td></tr></tbody></table></div></details></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>({ x = 4\n  y = 6 }, { x = 0\n  y = -1 })</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Item1</td><td>{ x = 4
//   y = 6 }</td></tr><tr><td>Item2</td><td>{ x = 0
//   y = -1 }</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ { x = 7
//   y = 9 }, { x = 7
//   y = 8 }, { x = 7
//   y = 7 }, { x = 6
//   y = 7 }, { x = 5
//   y = 7 }, { x = 4
//   y = 7 }, { x = 3
//   y = 7 }, { x = 2
//   y = 7 }, { x = 1
//   y = 7 }, { x = 1
//   y = 8 }, { x = 2
//   y = 8 }, { x = 3
//   y = 8 }, { x = 4
//   y = 8 }, { x = 5
//   y = 8 }, { x = 6
//   y = 8 }, { x = 6
//   y = 7 }, { x = 6
//   y = 6 }, { x = 6
//   y = 5 }, { x = 6
//   y = 4 }, { x = 5
//   y = 4 } ... (more) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ x = 7\n  y = 9 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>x</td><td><div class="dni-plaintext"><pre>7</pre></div></td></tr><tr><td>y</td><td><div class="dni-plaintext"><pre>9</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ { x = 7
//   y = 8 }, { x = 7
//   y = 7 }, { x = 6
//   y = 7 }, { x = 5
//   y = 7 }, { x = 4
//   y = 7 }, { x = 3
//   y = 7 }, { x = 2
//   y = 7 }, { x = 1
//   y = 7 }, { x = 1
//   y = 8 }, { x = 2
//   y = 8 }, { x = 3
//   y = 8 }, { x = 4
//   y = 8 }, { x = 5
//   y = 8 }, { x = 6
//   y = 8 }, { x = 6
//   y = 7 }, { x = 6
//   y = 6 }, { x = 6
//   y = 5 }, { x = 6
//   y = 4 }, { x = 5
//   y = 4 }, { x = 4
//   y = 4 } ... (more) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ x = 7\n  y = 8 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>x</td><td>7</td></tr><tr><td>y</td><td>8</td></tr></tbody></table></div></details></td></tr><tr><td>TailOrNull</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ { x = 7
//   y = 7 }, { x = 6
//   y = 7 }, { x = 5
//   y = 7 }, { x = 4
//   y = 7 }, { x = 3
//   y = 7 }, { x = 2
//   y = 7 }, { x = 1
//   y = 7 }, { x = 1
//   y = 8 }, { x = 2
//   y = 8 }, { x = 3
//   y = 8 }, { x = 4
//   y = 8 }, { x = 5
//   y = 8 }, { x = 6
//   y = 8 }, { x = 6
//   y = 7 }, { x = 6
//   y = 6 }, { x = 6
//   y = 5 }, { x = 6
//   y = 4 }, { x = 5
//   y = 4 }, { x = 4
//   y = 4 }, { x = 3
//   y = 4 } ... (more) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td><td>{ x = 7
//   y = 7 }</td></tr><tr><td>TailOrNull</td><td>[ { x = 6
//   y = 7 }, { x = 5
//   y = 7 }, { x = 4
//   y = 7 }, { x = 3
//   y = 7 }, { x = 2
//   y = 7 }, { x = 1
//   y = 7 }, { x = 1
//   y = 8 }, { x = 2
//   y = 8 }, { x = 3
//   y = 8 }, { x = 4
//   y = 8 }, { x = 5
//   y = 8 }, { x = 6
//   y = 8 }, { x = 6
//   y = 7 }, { x = 6
//   y = 6 }, { x = 6
//   y = 5 }, { x = 6
//   y = 4 }, { x = 5
//   y = 4 }, { x = 4
//   y = 4 }, { x = 3
//   y = 4 }, { x = 2
//   y = 4 } ... (more) ]</td></tr><tr><td>Head</td><td>{ x = 7
//   y = 7 }</td></tr><tr><td>Tail</td><td>[ { x = 6
//   y = 7 }, { x = 5
//   y = 7 }, { x = 4
//   y = 7 }, { x = 3
//   y = 7 }, { x = 2
//   y = 7 }, { x = 1
//   y = 7 }, { x = 1
//   y = 8 }, { x = 2
//   y = 8 }, { x = 3
//   y = 8 }, { x = 4
//   y = 8 }, { x = 5

// %%
File.ReadAllLines("input.txt") |> solution
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>[ 4903 ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@729[Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point],System.Int32]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+Map@749-1[Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point],System.Int32]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>mapping</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>FSI_0128+solution@101-19</code></span></summary><div><table><thead><tr></tr></thead><tbody></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td>ie</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ [ { x = 63
//   y = 129 }, { x = 63
//   y = 128 }, { x = 63
//   y = 127 }, { x = 63
//   y = 126 }, { x = 63
//   y = 125 }, { x = 63
//   y = 124 }, { x = 63
//   y = 123 }, { x = 63
//   y = 122 }, { x = 63
//   y = 121 }, { x = 63
//   y = 120 }, { x = 63
//   y = 119 }, { x = 63
//   y = 118 }, { x = 63
//   y = 117 }, { x = 63
//   y = 116 }, { x = 63
//   y = 115 }, { x = 63
//   y = 114 }, { x = 63
//   y = 113 }, { x = 63
//   y = 112 }, { x = 62
//   y = 112 }, { x = 61
//   y = 112 } ... (more) ] ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@729[System.Tuple`2[FSI_0128+Point,FSI_0128+Point],Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point]]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+Map@749-1[System.Tuple`2[FSI_0128+Point,FSI_0128+Point],Microsoft.FSharp.Collections.FSharpList`1[FSI_0128+Point]]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>mapping</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>FSI_0128+solution@98-20</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>map</td><td>[ [ Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Obstacle, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Obstacle, Space, Space, Obstacle, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space ... (more) ], [ Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space ... (more) ], [ Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Obstacle, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Space, Obstacle, Space, Space, Space, Space, Space, Space, Space, Space, Space ... (more) ], [ Space, Space, Space, Space, Space, Space, Space, Space, Space, Sp ...
//   y = 45 }, { x = 0
//   y = -1 }) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Microsoft.FSharp.Collections.SeqModule+revamp@729[Microsoft.FSharp.Core.FSharpOption`1[System.Tuple`2[FSI_0128+Point,FSI_0128+Point]],System.Tuple`2[FSI_0128+Point,FSI_0128+Point]]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>f</td><td>Microsoft.FSharp.Collections.SeqModule+Choose@778[Microsoft.FSharp.Core.FSharpOption`1[System.Tuple`2[FSI_0128+Point,FSI_0128+Point]],System.Tuple`2[FSI_0128+Point,FSI_0128+Point]]</td></tr><tr><td>ie</td><td>[ <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null>, <null> ... (more) ]</td></tr></tbody></table></div></details></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>({ x = 42\n  y = 45 }, { x = 0\n  y = -1 })</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Item1</td><td>{ x = 42
//   y = 45 }</td></tr><tr><td>Item2</td><td>{ x = 0
//   y = -1 }</td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details></td></tr><tr><td><i>(values)</i></td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>[ { x = 63
//   y = 129 }, { x = 63
//   y = 128 }, { x = 63
//   y = 127 }, { x = 63
//   y = 126 }, { x = 63
//   y = 125 }, { x = 63
//   y = 124 }, { x = 63
//   y = 123 }, { x = 63
//   y = 122 }, { x = 63
//   y = 121 }, { x = 63
//   y = 120 }, { x = 63
//   y = 119 }, { x = 63
//   y = 118 }, { x = 63
//   y = 117 }, { x = 63
//   y = 116 }, { x = 63
//   y = 115 }, { x = 63
//   y = 114 }, { x = 63
//   y = 113 }, { x = 63
//   y = 112 }, { x = 62
//   y = 112 }, { x = 61
//   y = 112 } ... (more) ]</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>HeadOrDefault</td>
